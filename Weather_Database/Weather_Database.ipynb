# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                          "Current Description": city_weather_desc,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of Set 1 | hilo
# Processing record 2 of Set 1 | atuona
# Processing record 3 of Set 1 | tasiilaq
# Processing record 4 of Set 1 | qaanaaq
# Processing record 5 of Set 1 | aklavik
# Processing record 6 of Set 1 | punta arenas
# Processing record 7 of Set 1 | salalah
# Processing record 8 of Set 1 | cayenne
# Processing record 9 of Set 1 | tevaitoa
# Processing record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing record 11 of Set 1 | busselton
# Processing record 12 of Set 1 | hermanus
# Processing record 13 of Set 1 | araouane
# Processing record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing record 15 of Set 1 | tiksi
# Processing record 16 of Set 1 | mahebourg
# Processing record 17 of Set 1 | cabo san lucas
# Processing record 18 of Set 1 | san ramon
# Processing record 19 of Set 1 | narsaq
# Processing record 20 of Set 1 | nanortalik
# Processing record 21 of Set 1 | half moon bay
# Processing record 22 of Set 1 | chuy
# Processing record 23 of Set 1 | acapulco
# Processing record 24 of Set 1 | clyde river
# Processing record 25 of Set 1 | nardaran
# Processing record 26 of Set 1 | mataura
# Processing record 27 of Set 1 | bengkulu
# Processing record 28 of Set 1 | ushuaia
# Processing record 29 of Set 1 | vikhorevka
# Processing record 30 of Set 1 | kapaa
# Processing record 31 of Set 1 | barrow
# Processing record 32 of Set 1 | honningsvag
# Processing record 33 of Set 1 | norman wells
# Processing record 34 of Set 1 | akdepe
# Processing record 35 of Set 1 | talara
# Processing record 36 of Set 1 | tuktoyaktuk
# Processing record 37 of Set 1 | kruisfontein
# Processing record 38 of Set 1 | ilulissat
# Processing record 39 of Set 1 | makinsk
# Processing record 40 of Set 1 | qinhuangdao
# Processing record 41 of Set 1 | saint-francois
# Processing record 42 of Set 1 | husavik
# Processing record 43 of Set 1 | port alfred
# Processing record 44 of Set 1 | lingao
# Processing record 45 of Set 1 | cidreira
# Processing record 46 of Set 1 | laguna
# Processing record 47 of Set 1 | rikitea
# Processing record 48 of Set 1 | cap malheureux
# Processing record 49 of Set 1 | matagami
# Processing record 50 of Set 1 | mount gambier
# Processing record 1 of Set 2 | novobirilyussy
# Processing record 2 of Set 2 | longyearbyen
# Processing record 3 of Set 2 | chapais
# Processing record 4 of Set 2 | bredasdorp
# Processing record 5 of Set 2 | ponta do sol
# Processing record 6 of Set 2 | qena
# Processing record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing record 8 of Set 2 | ishigaki
# Processing record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing record 10 of Set 2 | angoche
# Processing record 11 of Set 2 | mongo
# Processing record 12 of Set 2 | bantou
# Processing record 13 of Set 2 | albany
# Processing record 14 of Set 2 | san policarpo
# Processing record 15 of Set 2 | puerto ayora
# Processing record 16 of Set 2 | newport
# Processing record 17 of Set 2 | arraial do cabo
# Processing record 18 of Set 2 | bluff
# Processing record 19 of Set 2 | ambulu
# Processing record 20 of Set 2 | mar del plata
# Processing record 21 of Set 2 | manaure
# Processing record 22 of Set 2 | kifri
# Processing record 23 of Set 2 | hobart
# Processing record 24 of Set 2 | lebu
# Processing record 25 of Set 2 | butaritari
# Processing record 26 of Set 2 | malwan
# City not found. Skipping...
# Processing record 27 of Set 2 | san matias
# Processing record 28 of Set 2 | winnemucca
# Processing record 29 of Set 2 | zaykovo
# Processing record 30 of Set 2 | alexandria
# Processing record 31 of Set 2 | hami
# Processing record 32 of Set 2 | shakawe
# Processing record 33 of Set 2 | tura
# Processing record 34 of Set 2 | anadyr
# Processing record 35 of Set 2 | nantucket
# Processing record 36 of Set 2 | coihaique
# Processing record 37 of Set 2 | saint-pierre
# Processing record 38 of Set 2 | marovoay
# Processing record 39 of Set 2 | bilibino
# Processing record 40 of Set 2 | ribeira grande
# Processing record 41 of Set 2 | cape town
# Processing record 42 of Set 2 | daru
# Processing record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing record 44 of Set 2 | geraldton
# Processing record 45 of Set 2 | sapozhok
# Processing record 46 of Set 2 | vaini
# Processing record 47 of Set 2 | warwick
# Processing record 48 of Set 2 | tabiauea
# City not found. Skipping...
# Processing record 49 of Set 2 | mantua
# Processing record 50 of Set 2 | vaitupu
# City not found. Skipping...
# Processing record 1 of Set 3 | lazaro cardenas
# Processing record 2 of Set 3 | gondanglegi
# Processing record 3 of Set 3 | saldanha
# Processing record 4 of Set 3 | kaitangata
# Processing record 5 of Set 3 | platonovka
# Processing record 6 of Set 3 | havre-saint-pierre
# Processing record 7 of Set 3 | san benito
# Processing record 8 of Set 3 | fort nelson
# Processing record 9 of Set 3 | magnitogorsk
# Processing record 10 of Set 3 | khandyga
# Processing record 11 of Set 3 | kalmunai
# Processing record 12 of Set 3 | dabakala
# Processing record 13 of Set 3 | yellowknife
# Processing record 14 of Set 3 | pisco
# Processing record 15 of Set 3 | shimoda
# Processing record 16 of Set 3 | nome
# Processing record 17 of Set 3 | jilin
# Processing record 18 of Set 3 | sale
# Processing record 19 of Set 3 | talnakh
# Processing record 20 of Set 3 | sarangani
# Processing record 21 of Set 3 | bathsheba
# Processing record 22 of Set 3 | mint hill
# Processing record 23 of Set 3 | kodiak
# Processing record 24 of Set 3 | tawkar
# City not found. Skipping...
# Processing record 25 of Set 3 | rameswaram
# Processing record 26 of Set 3 | rungata
# City not found. Skipping...
# Processing record 27 of Set 3 | christchurch
# Processing record 28 of Set 3 | dzaoudzi
# Processing record 29 of Set 3 | sitka
# Processing record 30 of Set 3 | faanui
# Processing record 31 of Set 3 | tommot
# Processing record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing record 33 of Set 3 | eskasem
# City not found. Skipping...
# Processing record 34 of Set 3 | iwanai
# Processing record 35 of Set 3 | suicheng
# Processing record 36 of Set 3 | vila franca do campo
# Processing record 37 of Set 3 | araure
# Processing record 38 of Set 3 | la ronge
# Processing record 39 of Set 3 | saskylakh
# Processing record 40 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing record 41 of Set 3 | birjand
# Processing record 42 of Set 3 | chokurdakh
# Processing record 43 of Set 3 | mitchell
# Processing record 44 of Set 3 | cocachacra
# Processing record 45 of Set 3 | avera
# Processing record 46 of Set 3 | georgetown
# Processing record 47 of Set 3 | sur
# Processing record 48 of Set 3 | port lincoln
# Processing record 49 of Set 3 | coari
# Processing record 50 of Set 3 | sola
# Processing record 1 of Set 4 | avarua
# Processing record 2 of Set 4 | svetlyy
# Processing record 3 of Set 4 | nikolskoye
# Processing record 4 of Set 4 | bereda
# Processing record 5 of Set 4 | bankura
# Processing record 6 of Set 4 | kavieng
# Processing record 7 of Set 4 | tsihombe
# City not found. Skipping...
# Processing record 8 of Set 4 | biak
# Processing record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing record 10 of Set 4 | sao felix do xingu
# Processing record 11 of Set 4 | ugep
# Processing record 12 of Set 4 | souillac
# Processing record 13 of Set 4 | margate
# Processing record 14 of Set 4 | saint-philippe
# Processing record 15 of Set 4 | ancud
# Processing record 16 of Set 4 | sergeyevka
# Processing record 17 of Set 4 | tomatlan
# Processing record 18 of Set 4 | lensk
# Processing record 19 of Set 4 | lashio
# Processing record 20 of Set 4 | pecos
# Processing record 21 of Set 4 | tumkur
# Processing record 22 of Set 4 | aberdeen
# Processing record 23 of Set 4 | ozgon
# City not found. Skipping...
# Processing record 24 of Set 4 | vila velha
# Processing record 25 of Set 4 | axim
# Processing record 26 of Set 4 | baykit
# Processing record 27 of Set 4 | airai
# Processing record 28 of Set 4 | castro
# Processing record 29 of Set 4 | coahuayana
# Processing record 30 of Set 4 | tual
# Processing record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing record 32 of Set 4 | mangrol
# Processing record 33 of Set 4 | lavrentiya
# Processing record 34 of Set 4 | hithadhoo
# Processing record 35 of Set 4 | beyneu
# Processing record 36 of Set 4 | provideniya
# Processing record 37 of Set 4 | muisne
# Processing record 38 of Set 4 | phrai bung
# City not found. Skipping...
# Processing record 39 of Set 4 | hambantota
# Processing record 40 of Set 4 | sigli
# Processing record 41 of Set 4 | abaza
# Processing record 42 of Set 4 | marsa matruh
# Processing record 43 of Set 4 | itaituba
# Processing record 44 of Set 4 | sao filipe
# Processing record 45 of Set 4 | sao luiz gonzaga
# Processing record 46 of Set 4 | constitucion
# Processing record 47 of Set 4 | asau
# Processing record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing record 49 of Set 4 | san patricio
# Processing record 50 of Set 4 | iqaluit
# Processing record 1 of Set 5 | klaksvik
# Processing record 2 of Set 5 | victoria
# Processing record 3 of Set 5 | gamba
# Processing record 4 of Set 5 | comodoro rivadavia
# Processing record 5 of Set 5 | karaul
# City not found. Skipping...
# Processing record 6 of Set 5 | javanrud
# Processing record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing record 8 of Set 5 | polunochnoye
# Processing record 9 of Set 5 | tautira
# Processing record 10 of Set 5 | kungurtug
# Processing record 11 of Set 5 | bull savanna
# Processing record 12 of Set 5 | port elizabeth
# Processing record 13 of Set 5 | urdoma
# Processing record 14 of Set 5 | calvinia
# Processing record 15 of Set 5 | krasnoselkup
# Processing record 16 of Set 5 | aurillac
# Processing record 17 of Set 5 | usinsk
# Processing record 18 of Set 5 | muros
# Processing record 19 of Set 5 | andenes
# Processing record 20 of Set 5 | la mana
# Processing record 21 of Set 5 | bhandaria
# Processing record 22 of Set 5 | taoudenni
# Processing record 23 of Set 5 | thompson
# Processing record 24 of Set 5 | halifax
# Processing record 25 of Set 5 | innisfail
# Processing record 26 of Set 5 | cairns
# Processing record 27 of Set 5 | yulin
# Processing record 28 of Set 5 | ngukurr
# City not found. Skipping...
# Processing record 29 of Set 5 | itamarandiba
# Processing record 30 of Set 5 | kushiro
# Processing record 31 of Set 5 | hede
# Processing record 32 of Set 5 | maeriste
# Processing record 33 of Set 5 | churapcha
# Processing record 34 of Set 5 | caceres
# Processing record 35 of Set 5 | roald
# Processing record 36 of Set 5 | quelimane
# Processing record 37 of Set 5 | taizhou
# Processing record 38 of Set 5 | voh
# Processing record 39 of Set 5 | kutum
# Processing record 40 of Set 5 | jamestown
# Processing record 41 of Set 5 | kavaratti
# Processing record 42 of Set 5 | padang
# Processing record 43 of Set 5 | les cayes
# Processing record 44 of Set 5 | amapa
# Processing record 45 of Set 5 | tyumentsevo
# Processing record 46 of Set 5 | belaya gora
# Processing record 47 of Set 5 | faya
# Processing record 48 of Set 5 | isangel
# Processing record 49 of Set 5 | lata
# Processing record 50 of Set 5 | ostrovnoy
# Processing record 1 of Set 6 | broome
# Processing record 2 of Set 6 | mundo nuevo
# Processing record 3 of Set 6 | port hardy
# Processing record 4 of Set 6 | lasa
# Processing record 5 of Set 6 | mocambique
# City not found. Skipping...
# Processing record 6 of Set 6 | ust-kulom
# Processing record 7 of Set 6 | verkhoyansk
# Processing record 8 of Set 6 | vung tau
# Processing record 9 of Set 6 | teya
# Processing record 10 of Set 6 | nelson bay
# Processing record 11 of Set 6 | ixtapa
# Processing record 12 of Set 6 | new norfolk
# Processing record 13 of Set 6 | nakhon si thammarat
# Processing record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing record 15 of Set 6 | homer
# Processing record 16 of Set 6 | vagur
# Processing record 17 of Set 6 | saint george
# Processing record 18 of Set 6 | dongsheng
# Processing record 19 of Set 6 | loa janan
# Processing record 20 of Set 6 | nuuk
# Processing record 21 of Set 6 | teahupoo
# Processing record 22 of Set 6 | bokovskaya
# Processing record 23 of Set 6 | muroto
# Processing record 24 of Set 6 | big spring
# Processing record 25 of Set 6 | lompoc
# Processing record 26 of Set 6 | jacqueville
# Processing record 27 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing record 28 of Set 6 | sassandra
# Processing record 29 of Set 6 | alyangula
# Processing record 30 of Set 6 | shellbrook
# Processing record 31 of Set 6 | longlac
# City not found. Skipping...
# Processing record 32 of Set 6 | alofi
# Processing record 33 of Set 6 | khonuu
# City not found. Skipping...
# Processing record 34 of Set 6 | oussouye
# Processing record 35 of Set 6 | miri
# Processing record 36 of Set 6 | pevek
# Processing record 37 of Set 6 | mehamn
# Processing record 38 of Set 6 | riverton
# Processing record 39 of Set 6 | sunyani
# Processing record 40 of Set 6 | pozo colorado
# Processing record 41 of Set 6 | berlevag
# Processing record 42 of Set 6 | prince albert
# Processing record 43 of Set 6 | sesimbra
# Processing record 44 of Set 6 | east london
# Processing record 45 of Set 6 | fereydun kenar
# Processing record 46 of Set 6 | khatanga
# Processing record 47 of Set 6 | dabat
# Processing record 48 of Set 6 | kirakira
# Processing record 49 of Set 6 | esperance
# Processing record 50 of Set 6 | sobolevo
# Processing record 1 of Set 7 | signagi
# City not found. Skipping...
# Processing record 2 of Set 7 | prilep
# Processing record 3 of Set 7 | kampene
# Processing record 4 of Set 7 | mangai
# Processing record 5 of Set 7 | karakendzha
# City not found. Skipping...
# Processing record 6 of Set 7 | toftir
# City not found. Skipping...
# Processing record 7 of Set 7 | dolbeau
# City not found. Skipping...
# Processing record 8 of Set 7 | buala
# Processing record 9 of Set 7 | kaeo
# Processing record 10 of Set 7 | fortuna
# Processing record 11 of Set 7 | flinders
# Processing record 12 of Set 7 | smidovich
# Processing record 13 of Set 7 | iglesias
# Processing record 14 of Set 7 | wana
# Processing record 15 of Set 7 | kayerkan
# Processing record 16 of Set 7 | pandavapura
# Processing record 17 of Set 7 | nemuro
# Processing record 18 of Set 7 | cristalina
# Processing record 19 of Set 7 | zhetybay
# City not found. Skipping...
# Processing record 20 of Set 7 | vestmannaeyjar
# Processing record 21 of Set 7 | marawi
# Processing record 22 of Set 7 | simao
# Processing record 23 of Set 7 | dedza
# Processing record 24 of Set 7 | kaniama
# Processing record 25 of Set 7 | srednekolymsk
# Processing record 26 of Set 7 | pakwach
# City not found. Skipping...
# Processing record 27 of Set 7 | port blair
# Processing record 28 of Set 7 | shitanjing
# Processing record 29 of Set 7 | sinor
# Processing record 30 of Set 7 | tonneins
# Processing record 31 of Set 7 | north bend
# Processing record 32 of Set 7 | katsuura
# Processing record 33 of Set 7 | mumford
# Processing record 34 of Set 7 | klyuchi
# Processing record 35 of Set 7 | mouzakion
# City not found. Skipping...
# Processing record 36 of Set 7 | dese
# Processing record 37 of Set 7 | atar
# Processing record 38 of Set 7 | pachmarhi
# Processing record 39 of Set 7 | aflu
# City not found. Skipping...
# Processing record 40 of Set 7 | carnarvon
# Processing record 41 of Set 7 | barahona
# Processing record 42 of Set 7 | guerrero negro
# Processing record 43 of Set 7 | gizo
# Processing record 44 of Set 7 | tessalit
# Processing record 45 of Set 7 | bandarbeyla
# Processing record 46 of Set 7 | soyo
# Processing record 47 of Set 7 | jumla
# Processing record 48 of Set 7 | dikson
# Processing record 49 of Set 7 | zunyi
# Processing record 50 of Set 7 | codrington
# Processing record 1 of Set 8 | adrar
# Processing record 2 of Set 8 | mahibadhoo
# Processing record 3 of Set 8 | abha
# Processing record 4 of Set 8 | varhaug
# Processing record 5 of Set 8 | kajaani
# Processing record 6 of Set 8 | taltal
# Processing record 7 of Set 8 | chumikan
# Processing record 8 of Set 8 | saryshagan
# City not found. Skipping...
# Processing record 9 of Set 8 | lagoa
# Processing record 10 of Set 8 | maine-soroa
# Processing record 11 of Set 8 | kenai
# Processing record 12 of Set 8 | lamar
# Processing record 13 of Set 8 | itapirapua
# Processing record 14 of Set 8 | aporawan
# City not found. Skipping...
# Processing record 15 of Set 8 | oranjestad
# Processing record 16 of Set 8 | landskrona
# Processing record 17 of Set 8 | linxia
# Processing record 18 of Set 8 | tarabuco
# Processing record 19 of Set 8 | mackay
# Processing record 20 of Set 8 | cherskiy
# Processing record 21 of Set 8 | los llanos de aridane
# Processing record 22 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing record 23 of Set 8 | karangasem
# Processing record 24 of Set 8 | krasnyy yar
# Processing record 25 of Set 8 | bundaberg
# Processing record 26 of Set 8 | caravelas
# Processing record 27 of Set 8 | itumbiara
# Processing record 28 of Set 8 | berdigestyakh
# Processing record 29 of Set 8 | maragogi
# Processing record 30 of Set 8 | terenos
# Processing record 31 of Set 8 | brownwood
# Processing record 32 of Set 8 | chumphon
# Processing record 33 of Set 8 | khash
# Processing record 34 of Set 8 | bang saphan
# Processing record 35 of Set 8 | rehoboth
# Processing record 36 of Set 8 | monte patria
# Processing record 37 of Set 8 | brae
# Processing record 38 of Set 8 | hervey bay
# Processing record 39 of Set 8 | nishihara
# Processing record 40 of Set 8 | kloulklubed
# Processing record 41 of Set 8 | waiouru
# Processing record 42 of Set 8 | dodola
# Processing record 43 of Set 8 | murray bridge
# Processing record 44 of Set 8 | severo-kurilsk
# Processing record 45 of Set 8 | yabelo
# Processing record 46 of Set 8 | takoradi
# Processing record 47 of Set 8 | upernavik
# Processing record 48 of Set 8 | sorland
# Processing record 49 of Set 8 | cabra
# Processing record 50 of Set 8 | urambo
# Processing record 1 of Set 9 | surt
# Processing record 2 of Set 9 | nguiu
# City not found. Skipping...
# Processing record 3 of Set 9 | tornio
# Processing record 4 of Set 9 | pacific grove
# Processing record 5 of Set 9 | lyuban
# Processing record 6 of Set 9 | los algarrobos
# Processing record 7 of Set 9 | porto walter
# Processing record 8 of Set 9 | lorengau
# Processing record 9 of Set 9 | san pedro
# Processing record 10 of Set 9 | noumea
# Processing record 11 of Set 9 | panjab
# Processing record 12 of Set 9 | raga
# Processing record 13 of Set 9 | marsabit
# Processing record 14 of Set 9 | bubaque
# Processing record 15 of Set 9 | burnie
# Processing record 16 of Set 9 | xiongzhou
# Processing record 17 of Set 9 | luena
# Processing record 18 of Set 9 | hadejia
# Processing record 19 of Set 9 | waingapu
# Processing record 20 of Set 9 | katherine
# Processing record 21 of Set 9 | pacifica
# Processing record 22 of Set 9 | pangnirtung
# Processing record 23 of Set 9 | isiro
# Processing record 24 of Set 9 | asyut
# Processing record 25 of Set 9 | natitingou
# Processing record 26 of Set 9 | hofn
# Processing record 27 of Set 9 | cedar city
# Processing record 28 of Set 9 | nalut
# Processing record 29 of Set 9 | ouesso
# Processing record 30 of Set 9 | beihai
# Processing record 31 of Set 9 | kargasok
# Processing record 32 of Set 9 | las vegas
# Processing record 33 of Set 9 | cefalu
# Processing record 34 of Set 9 | nyurba
# Processing record 35 of Set 9 | tallahassee
# Processing record 36 of Set 9 | moose factory
# Processing record 37 of Set 9 | takhtamygda
# Processing record 38 of Set 9 | jalu
# Processing record 39 of Set 9 | kanata
# Processing record 40 of Set 9 | camacha
# Processing record 41 of Set 9 | darfo
# Processing record 42 of Set 9 | dandong
# Processing record 43 of Set 9 | kaihua
# Processing record 44 of Set 9 | damavand
# Processing record 45 of Set 9 | hasaki
# Processing record 46 of Set 9 | leningradskiy
# Processing record 47 of Set 9 | touros
# Processing record 48 of Set 9 | college
# Processing record 49 of Set 9 | bambous virieux
# Processing record 50 of Set 9 | jiwani
# Processing record 1 of Set 10 | dingle
# Processing record 2 of Set 10 | baoning
# Processing record 3 of Set 10 | mackenzie
# Processing record 4 of Set 10 | sakakah
# Processing record 5 of Set 10 | pozoblanco
# Processing record 6 of Set 10 | conde
# Processing record 7 of Set 10 | alanje
# Processing record 8 of Set 10 | chowchilla
# Processing record 9 of Set 10 | khorramshahr
# Processing record 10 of Set 10 | mayo
# Processing record 11 of Set 10 | salinopolis
# Processing record 12 of Set 10 | berbera
# Processing record 13 of Set 10 | san cristobal
# Processing record 14 of Set 10 | pocone
# Processing record 15 of Set 10 | ucluelet
# Processing record 16 of Set 10 | ust-tsilma
# Processing record 17 of Set 10 | beira
# Processing record 18 of Set 10 | noyabrsk
# Processing record 19 of Set 10 | kenora
# Processing record 20 of Set 10 | matamoros
# Processing record 21 of Set 10 | ternate
# Processing record 22 of Set 10 | sept-iles
# Processing record 23 of Set 10 | bestobe
# Processing record 24 of Set 10 | alice springs
# Processing record 25 of Set 10 | yeppoon
# Processing record 26 of Set 10 | samarinda
# Processing record 27 of Set 10 | yulara
# Processing record 28 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing record 29 of Set 10 | severomuysk
# Processing record 30 of Set 10 | derzhavinsk
# Processing record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing record 32 of Set 10 | fillan
# Processing record 33 of Set 10 | songea
# Processing record 34 of Set 10 | susaki
# Processing record 35 of Set 10 | medea
# Processing record 36 of Set 10 | carauari
# Processing record 37 of Set 10 | burns lake
# Processing record 38 of Set 10 | tuy hoa
# Processing record 39 of Set 10 | narok
# Processing record 40 of Set 10 | obigarm
# Processing record 41 of Set 10 | gubkinskiy
# Processing record 42 of Set 10 | port macquarie
# Processing record 43 of Set 10 | voi
# Processing record 44 of Set 10 | torbay
# Processing record 45 of Set 10 | svetlaya
# Processing record 46 of Set 10 | vostok
# Processing record 47 of Set 10 | kingseat
# Processing record 48 of Set 10 | anloga
# Processing record 49 of Set 10 | tortosa
# Processing record 50 of Set 10 | gazojak
# Processing record 1 of Set 11 | kerteh
# City not found. Skipping...
# Processing record 2 of Set 11 | inhambane
# Processing record 3 of Set 11 | bosaso
# Processing record 4 of Set 11 | caohai
# Processing record 5 of Set 11 | damietta
# Processing record 6 of Set 11 | itarema
# Processing record 7 of Set 11 | shubarkuduk
# Processing record 8 of Set 11 | yerbogachen
# Processing record 9 of Set 11 | wad madani
# Processing record 10 of Set 11 | beringovskiy
# Processing record 11 of Set 11 | iquique
# Processing record 12 of Set 11 | marcona
# City not found. Skipping...
# Processing record 13 of Set 11 | pangkalanbuun
# Processing record 14 of Set 11 | pangoa
# Processing record 15 of Set 11 | khandbari
# Processing record 16 of Set 11 | gornopravdinsk
# Processing record 17 of Set 11 | ugoofaaru
# Processing record 18 of Set 11 | baykalovo
# Processing record 19 of Set 11 | lafia
# Processing record 20 of Set 11 | veraval
# Processing record 21 of Set 11 | deputatskiy
# Processing record 22 of Set 11 | rorvik
# Processing record 23 of Set 11 | woodstock
# Processing record 24 of Set 11 | alekseyevsk
# Processing record 25 of Set 11 | mayor pablo lagerenza
# Processing record 26 of Set 11 | tias
# Processing record 27 of Set 11 | wufeng
# Processing record 28 of Set 11 | rusape
# Processing record 29 of Set 11 | el tigre
# Processing record 30 of Set 11 | bilma
# Processing record 31 of Set 11 | san carlos de bariloche
# Processing record 32 of Set 11 | kabinda
# Processing record 33 of Set 11 | agadez
# Processing record 34 of Set 11 | salym
# Processing record 35 of Set 11 | vaculesti
# Processing record 36 of Set 11 | albolote
# Processing record 37 of Set 11 | sorvag
# City not found. Skipping...
# Processing record 38 of Set 11 | tocopilla
# Processing record 39 of Set 11 | melfort
# Processing record 40 of Set 11 | portland
# Processing record 41 of Set 11 | piterka
# Processing record 42 of Set 11 | evensk
# Processing record 43 of Set 11 | saryg-sep
# Processing record 44 of Set 11 | mandalgovi
# Processing record 45 of Set 11 | namtsy
# Processing record 46 of Set 11 | grand-santi
# Processing record 47 of Set 11 | nabire
# Processing record 48 of Set 11 | namatanai
# Processing record 49 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing record 50 of Set 11 | cupertino
# Processing record 1 of Set 12 | smirnykh
# Processing record 2 of Set 12 | olinda
# Processing record 3 of Set 12 | douentza
# Processing record 4 of Set 12 | komsomolskiy
# Processing record 5 of Set 12 | meulaboh
# Processing record 6 of Set 12 | kahului
# Processing record 7 of Set 12 | jizan
# Processing record 8 of Set 12 | flin flon
# Processing record 9 of Set 12 | dondo
# Processing record 10 of Set 12 | puerto madryn
# Processing record 11 of Set 12 | seoul
# Processing record 12 of Set 12 | nioro
# Processing record 13 of Set 12 | korla
# Processing record 14 of Set 12 | harper
# Processing record 15 of Set 12 | ertil
# Processing record 16 of Set 12 | puerto el triunfo
# Processing record 17 of Set 12 | zhangjiakou
# Processing record 18 of Set 12 | grand gaube
# Processing record 19 of Set 12 | rock sound
# Processing record 20 of Set 12 | ulagan
# Processing record 21 of Set 12 | tiznit
# Processing record 22 of Set 12 | tocache
# Processing record 23 of Set 12 | borovichi
# Processing record 24 of Set 12 | bethel
# Processing record 25 of Set 12 | slave lake
# Processing record 26 of Set 12 | wagar
# Processing record 27 of Set 12 | shelburne
# Processing record 28 of Set 12 | mapastepec
# Processing record 29 of Set 12 | aripuana
# Processing record 30 of Set 12 | esquipulas
# Processing record 31 of Set 12 | severo-yeniseyskiy
# Processing record 32 of Set 12 | roma
# Processing record 33 of Set 12 | chiredzi
# Processing record 34 of Set 12 | huaicheng
# Processing record 35 of Set 12 | rypefjord
# Processing record 36 of Set 12 | lumphat
# Processing record 37 of Set 12 | nador
# Processing record 38 of Set 12 | zlynka
# Processing record 39 of Set 12 | de-kastri
# Processing record 40 of Set 12 | masuguru
# Processing record 41 of Set 12 | necochea
# Processing record 42 of Set 12 | chandbali
# Processing record 43 of Set 12 | balabac
# Processing record 44 of Set 12 | oxford
# Processing record 45 of Set 12 | eyl
# Processing record 46 of Set 12 | the valley
# Processing record 47 of Set 12 | sampit
# Processing record 48 of Set 12 | erzin
# Processing record 49 of Set 12 | marienburg
# Processing record 50 of Set 12 | xai-xai
# Processing record 1 of Set 13 | tayoltita
# Processing record 2 of Set 13 | cilegon
# Processing record 3 of Set 13 | sydney mines
# Processing record 4 of Set 13 | olafsvik
# Processing record 5 of Set 13 | charagua
# Processing record 6 of Set 13 | ejura
# Processing record 7 of Set 13 | higuey
# City not found. Skipping...
# Processing record 8 of Set 13 | chor
# Processing record 9 of Set 13 | narayangarh
# Processing record 10 of Set 13 | ruzomberok
# Processing record 11 of Set 13 | semey
# Processing record 12 of Set 13 | vikulovo
# Processing record 13 of Set 13 | tianpeng
# Processing record 14 of Set 13 | drinovci
# Processing record 15 of Set 13 | batagay
# Processing record 16 of Set 13 | yar-sale
# Processing record 17 of Set 13 | candawaga
# City not found. Skipping...
# Processing record 18 of Set 13 | ouadda
# Processing record 19 of Set 13 | satara
# Processing record 20 of Set 13 | santa cruz
# Processing record 21 of Set 13 | hamilton
# Processing record 22 of Set 13 | monte alegre
# Processing record 23 of Set 13 | portage
# Processing record 24 of Set 13 | masyaf
# Processing record 25 of Set 13 | virginia beach
# Processing record 26 of Set 13 | ambunti
# Processing record 27 of Set 13 | sungaipenuh
# Processing record 28 of Set 13 | champerico
# Processing record 29 of Set 13 | houma
# Processing record 30 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing record 31 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing record 32 of Set 13 | khani
# Processing record 33 of Set 13 | nizhniy ingash
# Processing record 34 of Set 13 | carbondale
# Processing record 35 of Set 13 | saint-augustin
# Processing record 36 of Set 13 | ketchikan
# Processing record 37 of Set 13 | sao joao da barra
# Processing record 38 of Set 13 | mahanoro
# Processing record 39 of Set 13 | broken hill
# Processing record 40 of Set 13 | sinnamary
# Processing record 41 of Set 13 | banda aceh
# Processing record 42 of Set 13 | aden
# Processing record 43 of Set 13 | sal rei
# Processing record 44 of Set 13 | dunedin
# Processing record 45 of Set 13 | upata
# Processing record 46 of Set 13 | cabedelo
# Processing record 47 of Set 13 | palma
# Processing record 48 of Set 13 | alta floresta
# Processing record 49 of Set 13 | makakilo city
# Processing record 50 of Set 13 | havoysund
# Processing record 1 of Set 14 | waddan
# Processing record 2 of Set 14 | shima
# Processing record 3 of Set 14 | pringsewu
# Processing record 4 of Set 14 | otautau
# Processing record 5 of Set 14 | port-gentil
# Processing record 6 of Set 14 | awbari
# Processing record 7 of Set 14 | wanning
# Processing record 8 of Set 14 | maues
# Processing record 9 of Set 14 | owando
# Processing record 10 of Set 14 | louisbourg
# City not found. Skipping...
# Processing record 11 of Set 14 | tromso
# Processing record 12 of Set 14 | fukue
# Processing record 13 of Set 14 | roebourne
# Processing record 14 of Set 14 | tynda
# Processing record 15 of Set 14 | baryshivka
# Processing record 16 of Set 14 | kathu
# Processing record 17 of Set 14 | marsh harbour
# Processing record 18 of Set 14 | toliary
# City not found. Skipping...
# Processing record 19 of Set 14 | luau
# Processing record 20 of Set 14 | tazovskiy
# Processing record 21 of Set 14 | luganville
# Processing record 22 of Set 14 | puerto escondido
# Processing record 23 of Set 14 | sivas
# Processing record 24 of Set 14 | tobermory
# Processing record 25 of Set 14 | kirksville
# Processing record 26 of Set 14 | lillooet
# Processing record 27 of Set 14 | okakarara
# Processing record 28 of Set 14 | nidzica
# Processing record 29 of Set 14 | manyoni
# Processing record 30 of Set 14 | sukumo
# Processing record 31 of Set 14 | vanimo
# Processing record 32 of Set 14 | saint anthony
# Processing record 33 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing record 34 of Set 14 | novoagansk
# Processing record 35 of Set 14 | bara
# Processing record 36 of Set 14 | ambanja
# Processing record 37 of Set 14 | aljezur
# Processing record 38 of Set 14 | tabas
# Processing record 39 of Set 14 | ferrol
# Processing record 40 of Set 14 | warqla
# City not found. Skipping...
# Processing record 41 of Set 14 | zhigansk
# Processing record 42 of Set 14 | qasigiannguit
# Processing record 43 of Set 14 | vardo
# Processing record 44 of Set 14 | tigil
# Processing record 45 of Set 14 | bruhl
# Processing record 46 of Set 14 | najran
# Processing record 47 of Set 14 | banyo
# Processing record 48 of Set 14 | rexburg
# Processing record 49 of Set 14 | gorontalo
# Processing record 50 of Set 14 | kargopol
# Processing record 1 of Set 15 | kortkeros
# Processing record 2 of Set 15 | cam ranh
# Processing record 3 of Set 15 | nhulunbuy
# Processing record 4 of Set 15 | poum
# Processing record 5 of Set 15 | lanuza
# Processing record 6 of Set 15 | nevsehir
# Processing record 7 of Set 15 | vaitape
# Processing record 8 of Set 15 | phonhong
# Processing record 9 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing record 10 of Set 15 | savannah bight
# Processing record 11 of Set 15 | sao joao do paraiso
# Processing record 12 of Set 15 | hovd
# Processing record 13 of Set 15 | tabora
# Processing record 14 of Set 15 | itoman
# Processing record 15 of Set 15 | vao
# Processing record 16 of Set 15 | mahemdavad
# Processing record 17 of Set 15 | jahrom
# City not found. Skipping...
# Processing record 18 of Set 15 | karla
# Processing record 19 of Set 15 | raahe
# Processing record 20 of Set 15 | aksha
# Processing record 21 of Set 15 | tongchuan
# Processing record 22 of Set 15 | elko
# Processing record 23 of Set 15 | akyab
# Processing record 24 of Set 15 | bargal
# City not found. Skipping...
# Processing record 25 of Set 15 | surakarta
# Processing record 26 of Set 15 | novobelokatay
# Processing record 27 of Set 15 | teguise
# Processing record 28 of Set 15 | arkhangelskoye
# Processing record 29 of Set 15 | altay
# Processing record 30 of Set 15 | huntingdon
# Processing record 31 of Set 15 | paamiut
# Processing record 32 of Set 15 | yavaros
# Processing record 33 of Set 15 | isabela
# Processing record 34 of Set 15 | bowling green
# Processing record 35 of Set 15 | semnan
# Processing record 36 of Set 15 | hay river
# Processing record 37 of Set 15 | yambio
# Processing record 38 of Set 15 | hualmay
# Processing record 39 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing record 40 of Set 15 | hachinohe
# Processing record 41 of Set 15 | ulladulla
# Processing record 42 of Set 15 | pilar
# Processing record 43 of Set 15 | prestea
# Processing record 44 of Set 15 | strezhevoy
# Processing record 45 of Set 15 | zdvinsk
# Processing record 46 of Set 15 | biasca
# Processing record 47 of Set 15 | san jeronimo
# Processing record 48 of Set 15 | atyrau
# Processing record 49 of Set 15 | coquimbo
# Processing record 50 of Set 15 | taburi
# City not found. Skipping...
# Processing record 1 of Set 16 | umm lajj
# Processing record 2 of Set 16 | bonthe
# Processing record 3 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing record 4 of Set 16 | olpe
# Processing record 5 of Set 16 | fort dodge
# Processing record 6 of Set 16 | chara
# Processing record 7 of Set 16 | alihe
# Processing record 8 of Set 16 | novoye leushino
# Processing record 9 of Set 16 | sampang
# Processing record 10 of Set 16 | natal
# Processing record 11 of Set 16 | aniva
# Processing record 12 of Set 16 | walvis bay
# Processing record 13 of Set 16 | mutare
# Processing record 14 of Set 16 | havre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          Hilo  19.7297 -155.0900     72.81       moderate rain        96
# 1        Atuona  -9.8000 -139.0333     78.57           clear sky        79
# 2      Tasiilaq  65.6145  -37.6368     26.76     overcast clouds        56
# 3       Qaanaaq  77.4840  -69.3632      1.54     overcast clouds        77
# 4       Aklavik  68.2191 -135.0107    -12.17          light snow        97
# 5  Punta Arenas -53.1500  -70.9167     44.71          few clouds        65
# 6       Salalah  17.0151   54.0924     75.29           clear sky        46
# 7       Cayenne   4.9333  -52.3333     81.09           clear sky        86
# 8      Tevaitoa -16.7833 -151.5000     82.08           clear sky        75
# 9     Busselton -33.6500  115.3333     77.70       broken clouds        42
#
#    Cloudiness  Wind Speed Country
# 0          90        5.75      US
# 1           7       17.98      PF
# 2         100        8.75      GL
# 3         100        5.99      GL
# 4         100       14.38      CA
# 5          20       14.97      CL
# 6           0        4.61      OM
# 7           0        1.14      GF
# 8           9       16.22      PF
# 9          54        6.35      AU

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US  19.7297 -155.0900     72.81        96          90
# 1        Atuona      PF  -9.8000 -139.0333     78.57        79           7
# 2      Tasiilaq      GL  65.6145  -37.6368     26.76        56         100
# 3       Qaanaaq      GL  77.4840  -69.3632      1.54        77         100
# 4       Aklavik      CA  68.2191 -135.0107    -12.17        97         100
# 5  Punta Arenas      CL -53.1500  -70.9167     44.71        65          20
# 6       Salalah      OM  17.0151   54.0924     75.29        46           0
# 7       Cayenne      GF   4.9333  -52.3333     81.09        86           0
# 8      Tevaitoa      PF -16.7833 -151.5000     82.08        75           9
# 9     Busselton      AU -33.6500  115.3333     77.70        42          54
#
#    Wind Speed Current Description
# 0        5.75       moderate rain
# 1       17.98           clear sky
# 2        8.75     overcast clouds
# 3        5.99     overcast clouds
# 4       14.38          light snow
# 5       14.97          few clouds
# 6        4.61           clear sky
# 7        1.14           clear sky
# 8       16.22           clear sky
# 9        6.35       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
